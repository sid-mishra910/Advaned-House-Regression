# %% [markdown]
# <a href="https://colab.research.google.com/github/sid-mishra910/Advaned-House-Regression/blob/master/house_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/
# Out:
# /content/drive

# %%
ls
# Out:
# 'My Drive'/

# %%
cd My Drive
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
#  1_client.c.gdoc
# 'Activity Modeling.gslides'
#  A-Netflix/
# 'Anyfile Notepad Files'/
# 'Anyfile Notepad Files (1)'/
# 'Boulevard Of Broken Dreams.pdf'
#  BTP/
# 'Colab Notebooks'/
# 'coordinator final.pdf'
# 'Copy of Distributed File System.gdoc'
# 'Design 2(1).gslides'
# 'Distributed File System.gdoc'
# 'Document from Siddharth Mishra (1).pdf'
# 'Document from Siddharth Mishra (2).pdf'
# 'Document from Siddharth Mishra (3).pdf'
# 'Document from Siddharth Mishra.pdf'
# 'EEO_Self-Identification_Form_2020 (1).gdoc'
#  EEO_Self-Identification_Form_2020.doc
#  EEO_Self-Identification_Form_2020.gdoc
# 'EHD Project Proposal.gdoc'
# 'EL 203_Module 2 & 3_2017.gslides'
# 'EL 203 _Module 4-6_2017.gslides'
#  EmiratesTicket1.pdf
#  EmiratesTicket2.pdf
#  epdf.tips_the-complete-verilog-book.pdf
#  EVS.rtf.rtf.gdoc
# 'Fall 2019 Availability Form GWC and GSC.gsheet'
# 'Fall 2019 Availability Form GWC and GSC.xls'
#  House_Pred/
# 'How to get started with Drive.pdf'
#  IMG_20171223_113952.jpg
# ...

# %%
cd House_Pred/
# Out:
# /content/drive/My Drive/House_Pred

# %%
ls
# Out:
# data_description.txt  sample_submission.csv  train.csv
# formulatedtest.csv    test.csv

# %%
import pandas as pd
train_csv = pd.read_csv('train.csv')

# %%
train_csv.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
import numpy as np
import matplotlib as mlt

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.heatmap(train_csv.isnull(),yticklabels=False,cbar=False)

# %%
train_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_csv['LotFrontage']=train_csv['LotFrontage'].fillna(train_csv['LotFrontage'].mean())

# %%
train_csv.drop('Alley',axis=1,inplace = None)
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 80 columns]

# %%
train_csv.shape
# Out:
# (1460, 81)

# %%
train_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_csv['MasVnrArea'] = train_csv['MasVnrArea'].fillna(train_csv['MasVnrArea'].mode()[0])

# %%
train_csv['MasVnrType'] = train_csv['MasVnrType'].fillna(train_csv['MasVnrType'].mode()[0])

# %%
train_csv['BsmtQual'] = train_csv['BsmtQual'].fillna(train_csv['MasVnrType'].mode()[0])

# %%
train_csv['BsmtCond'] = train_csv['BsmtCond'].fillna(train_csv['BsmtCond'].mode()[0])
train_csv['BsmtExposure'] = train_csv['BsmtExposure'].fillna(train_csv['BsmtExposure'].mode()[0])
train_csv['BsmtFinType1'] = train_csv['BsmtFinType1'].fillna(train_csv['BsmtFinType1'].mode()[0])
train_csv['BsmtFinType2'] = train_csv['BsmtFinType2'].fillna(train_csv['BsmtFinType2'].mode()[0])

# %%
train_csv['Electrical'] = train_csv['Electrical'].fillna(train_csv['Electrical'].mode()[0])
train_csv['FireplaceQu'] = train_csv['FireplaceQu'].fillna(train_csv['FireplaceQu'].mode()[0])

# %%
train_csv['GarageType']=train_csv['GarageType'].fillna(train_csv['GarageType'].mode()[0])

# %%
train_csv['GarageFinish'] = train_csv['GarageFinish'].fillna(train_csv['GarageFinish'].mode()[0])

# %%
train_csv['GarageQual'] = train_csv['GarageQual'].fillna(train_csv['GarageQual'].mode()[0])
train_csv['GarageCond'] = train_csv['GarageCond'].fillna(train_csv['GarageCond'].mode()[0])

# %%
train_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_csv.drop('Alley',axis=1,inplace=True)

# %%
train_csv.shape
# Out:
# (1460, 80)

# %%
train_csv.drop(['PoolQC','Fence','MiscFeature','GarageYrBlt'],axis=1,inplace=True)

# %%
train_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
train_csv.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64

# %%
sns.heatmap(train_csv.isnull(),yticklabels=False,cbar=False)

# %%
train_csv.shape
# Out:
# (1460, 76)

# %%
train_csv.dropna(inplace=True)

# %%
train_csv.shape
# Out:
# (1460, 76)

# %%
list(train_csv.columns.values)
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
# ...

# %%
columns = list(train_csv.columns.values)

# %%
len(columns)
# Out:
# 76

# %%
columns=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional',
         'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive']

# %%
train_csv.drop('Id',axis=1,inplace=True)

# %%
train_csv.shape
# Out:
# (1460, 75)

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([final_df,df_final],axis=1)
        
    return df_final

# %%
main_df = train_csv.copy()

# %%
test_csv = pd.read_csv('formulatedtest.csv')

# %%
test_csv.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          20       RH         80.0  ...    2010       WD        Normal
# 1          20       RL         81.0  ...    2010       WD        Normal
# 2          60       RL         74.0  ...    2010       WD        Normal
# 3          60       RL         78.0  ...    2010       WD        Normal
# 4         120       RL         43.0  ...    2010       WD        Normal
#
# [5 rows x 74 columns]

# %%
final_df = pd.concat([train_csv, test_csv],axis=0)

# %%
final_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# 0          60       RL         65.0  ...        WD        Normal  208500.0
# 1          20       RL         80.0  ...        WD        Normal  181500.0
# 2          60       RL         68.0  ...        WD        Normal  223500.0
# 3          70       RL         60.0  ...        WD       Abnorml  140000.0
# 4          60       RL         84.0  ...        WD        Normal  250000.0
#
# [5 rows x 75 columns]

# %%
final_df.shape
# Out:
# (2919, 75)

# %%
final_df = category_onehot_multcols(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %%
final_df.shape
# Out:
# (2919, 176)

# %%
final_df = final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  ...  CarPort  Detchd  RFn  P
# 0          60         65.0     8450            7  ...        0       0    1  0
# 1          20         80.0     9600            6  ...        0       0    1  0
# 2          60         68.0    11250            7  ...        0       0    1  0
# 3          70         60.0     9550            7  ...        0       1    0  0
# 4          60         84.0    14260            8  ...        0       0    1  0
#
# [5 rows x 176 columns]

# %%
train_fin = final_df.iloc[:1420,:]

# %%
test_fin = final_df.iloc[1420:,:]

# %%
test_fin.shape
# Out:
# (1499, 176)

# %%
test_fin.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X_train = train_fin.drop(['SalePrice'],axis=1)

# %%
Y_train = train_fin['SalePrice']

# %%
Y_train
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1415    175900.0
# 1416    122500.0
# 1417    340000.0
# 1418    124000.0
# 1419    223000.0
# Name: SalePrice, Length: 1420, dtype: float64

# %%
import xgboost as xgb

# %%
classifier = xgb.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
       n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=True, subsample=1)

# %%
classifier.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=True, subsample=1, verbosity=1)

# %%
y_pred = classifier.predict(test_fin)

# %%
y_pred
# Out:
# array([156820.75 , 140251.69 , 136878.52 , ..., 178942.3  , 123590.414,
#        236207.28 ], dtype=float32)

# %%
sub_sample = pd.read_csv('sample_submission.csv')

# %%
y_pred_df = pd.DataFrame(y_pred)

# %%
sub_fin = pd.concat([sub_sample['Id'],y_pred_df],axis=1)

# %%
sub_fin.head()
# Out:
#        Id              0
# 0  1461.0  156820.750000
# 1  1462.0  140251.687500
# 2  1463.0  136878.515625
# 3  1464.0  183256.859375
# 4  1465.0  134037.328125

# %%
sub_fin.shape
# Out:
# (1499, 2)

# %%
sub_fin.columns =['Id','SalePrice']

# %%
sub_fin.head()
# Out:
#        Id      SalePrice
# 0  1461.0  156820.750000
# 1  1462.0  140251.687500
# 2  1463.0  136878.515625
# 3  1464.0  183256.859375
# 4  1465.0  134037.328125

# %%
sub_fin['Id'] = sub_fin['Id'].apply(np.int64)

# %%
sub_fin.dropna(axis=0,inplace= True)

# %%
sub_fin.shape
# Out:
# (1459, 2)

# %%
sub_fin.isnull()
# Out:
#          Id  SalePrice
# 0     False      False
# 1     False      False
# 2     False      False
# 3     False      False
# 4     False      False
# ...     ...        ...
# 1454  False      False
# 1455  False      False
# 1456  False      False
# 1457  False      False
# 1458  False      False
#
# [1459 rows x 2 columns]

# %%
sub_fin
# Out:
#         Id      SalePrice
# 0     1461  136894.015625
# 1     1462  186612.875000
# 2     1463  133731.328125
# 3     1464  138765.234375
# 4     1465  251981.796875
# ...    ...            ...
# 1454  2915  132712.734375
# 1455  2916  168008.921875
# 1456  2917  141272.796875
# 1457  2918   94184.992188
# 1458  2919  157454.609375
#
# [1459 rows x 2 columns]

# %%
sub_fin.to_csv('submission.csv',index=False)

# %%
regressor=xgb.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
       n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=True, subsample=1)
